# %%
import random

male_names = [
      "Ming", "Wai", "Ho", "Fai", "Chiu", "Kwan", "Yat", "Kin", "Tsz", "Fung",
    "Chung", "Hang", "Sik", "Chun", "Shing", "Hao", "Ting", "Shun", "Man", "Sing",
    "Chit", "Keung", "Bun", "Kiu", "Ying", "Cheung", "Siu", "Ting", "Wai", 
    "Chi", "Ho", "Kit", "Ming", "Yin", "Yip", "Fai", "Hung", "Yat", "Wai", 
    "Choi", "Siu", "Ming", "Kwan", "Ho", "Chit", "Hong", "Tung", "Yung", 
    "Ki", "Wai", "Shing", "Yat", "Ming", "Ying", "Ho", "Kin", "Chung", 
    "Fai", "Sik", "Hang", "Cheung", "Yin", "Fai", "Ho", "Sik", "Shun", 
    "Kwan", "Chiu", "Kin", "Hung", "Cheung", "Chiu", "Ming", "Shing", 
    "Wai", "Man", "Sik", "Kwan", "Fai", "Kin", "Yat", "Ho", "Chung", 
    "Hao", "Ming", "Ho", "Wai", "Ting", "Fai", "Cheung", "Ming", "Sik", 
    "Ho", "Ying", "Kwan", "Chit", "Man", "Wai", "Yat", "Chiu", "Kit",
    "Yat", "Chun", "Chit", "Kin", "Fung", "Ming", "Wai", "Ying", "Shun", 
    "Wai", "Cheung", "Sik", "Yat", "Wai", "Chun", "Wai", "Sik", "Fai",
     "Jun", "Wei", "Xiong", "Rong", "Zhi", "Tian", "Hao", "Jie", "Bo", "Gang",
    "Long", "Qiang", "Xiang", "Peng", "Zheng", "Chao", "Yun", "Xue", "Zhihao", "Shuo",
    "Rui", "Wei" ,"hao", "Jian", "Feng", "Tao",  "Kai", "Jun", "Zhi", "Xiang", "Yuan",
    "Heng", "Qin", "Tao", "Shen", "Jin",
    "Xun", "Deng", "Zhong", "Cheng", "Mao",
    "Xue", "Jie", "Zhen", "Guo", "Liang",
    "Yuan", "Cheng", "Yue", "Xing", "Qiao",
    "Feng", "Jian", "Hui", "Tian", "Rong",
    "Song", "Bing", "Zhao", "Zheng", "Zhu",
    "Xing", "Hao", "Wei", "Shu", "Xie",
    "Ning", "Yong", "Zhi", "Jiang", "Li",
    "Shuai", "Yun", "Zhi", "Guang", "Ting",
    "Ming", "Sheng", "En", "Kai", "Yan"
]

female_names = [
     "Mei", "Ling", "Man", "Yee", "Pui", "Sze", "Hoi", "Yan", "Ching", "Yu",
    "Fong", "Ting", "Siu", "Hui", "Wai", "Chun", "Kwan", "Choi", "Ying", "Suk",
    "Wai", "Yat", "Fai", "Ming", "Suk", "Chai", "Pang", "Ning", "Hing", "Ying",
    "Siu", "Man", "Mei", "Ling", "Yee", "Man", "Pui", "Ying", "Sze", "Yu", 
    "Ching", "Yee", "Ying", "Mei", "Ting", "Yu", "Hoi", "Ying", "Chun", "Man", 
    "Wong", "Choi", "Man", "Yat", "Fai", "Suk", "Wai", "Ching", "Fong", 
    "Yee", "Siu", "Ching", "Ling", "Yi", "Chun", "Fong", "Ying", "Choi", 
    "Pui", "Ching", "Sze", "Fong", "Man", "Yee", "Ching", "Fai", "Yee", 
    "Wan", "Suk", "Fong", "Mei", "Choi", "Wai", "Yi", "Chun", "Ying", 
    "Ying", "Fai", "Hui", "Man", "Pang", "Fong", "Ning", "Ching", "Siu", 
    "Wai", "Ting", "Man", "Mei", "Fong", "Ling", "Sze", "Yee", "Ching", 
    "Pui", "Mei", "Sze", "Man", "Ching", "Suk", "Hui", "Ying", "Hoi", 
    "Fong", "Ying", "Ting", "Wai", "Wan", "Choi", "Fong", "Yat", "Mei", 
    "Fong", "Man", "Siu", "Ying", "Mei", "Suk", "Ling", "Ching", "Yee", 
    "Fong", "Pui", "Wan", "Suk", "Choi", "Chun", "Wai", "Wai", "Fong", 
    "Ting", "Choi", "Hing", "Man", "Ying", "Man", "Chun", "Mei", "Ling", 
    "Yee", "Pui", "Sze", "Hui", "Ching", "Ying", "Ting", "Wai", "Man",
      "Mei", "Ling", "Man", "Yee", "Pui", "Xiu", "Fang", "Jing", "Li", "Qin",
    "Ting", "Yan", "Hui", "Xuan", "Ning",     "Shan", "Lian", "Xia", "Ying", "Qiao",
    "Zhen", "Ling", "Yuan", "Fen", "Mei",    "Jiao", "Li", "Ning", "Fen", "Mei",
    "Ying", "Hui", "Yan", "Shao", "Xiu",
    "Lan", "Ying", "Yu", "Qin", "Sui",
    "Fang", "Jing", "Lian", "Xia", "Qiao",
    "Zhen", "Ling", "Yuan", "Fen", "Mei",
    "Sze", "Hoi", "Yan", "Ching", "Yu",
    "Xuan", "Hui", "Ying", "Ting", "Xia",
    "Qing", "Zhi", "Rong", "Jing", "Ming",
    "Ting", "Yun", "Hua", "Xing", "Yin",
    "Xiao", "Nan", "Jing", "Chun", "Ping"
    "Sze", "Hoi", "Yan", "Ching", "Yu"
    
]

male_names_en = [
    "Jason", "Michael", "David", "James", "John",
    "Robert", "William", "Daniel", "Matthew", "Andrew",
     "Christopher", "Joshua", "Daniel", "Matthew", "Joseph",
    "Charles", "Thomas", "Kevin", "Brian", "Ethan",   "Nathan", "Aaron", "Adam", "Ryan", "Jack",
    "Samuel", "Dylan", "Luke", "Henry", "Oliver", "Isaac", "Gabriel", "Anthony", "Jordan", "Charles",
    "Jaxon", "Levi", "Aaron", "Adam", "Miles",
    "Hunter", "Eli", "Caleb", "Wyatt", "Isaiah",
    "Asher", "Thomas", "Landon", "Cameron", "Jasper",
    "Silas", "Nolan", "Vincent", "Zachary", "Xander",
    "Cooper", "Gavin", "Ryder", "Sawyer", "Maverick"
    
]

female_names_en = [
    "Emily", "Jessica", "Sarah", "Ashley", "Amanda",
    "Jennifer", "Elizabeth", "Samantha", "Michelle", "Laura",  "Olivia", "Sophia", "Isabella", "Mia", "Ava",
    "Charlotte", "Amelia", "Harper", "Grace", "Chloe",
       "Ella", "Scarlett", "Victoria", "Lily", "Zoe",
    "Aria", "Addison", "Nora", "Riley", "Hannah",
     "Sofia", "Ariana", "Bella", "Autumn", "Savannah",
    "Skylar", "Kinsley", "Piper", "Violet", "Lucy",
    "Stella", "Claire", "Sadie", "Alyssa", "Madison",
    "Elena", "Katherine", "Lydia", "Jasmine", "Naomi",
    "Maya", "Julia", "Cora", "Addilyn", "Emilia",
    "Lila", "Tessa", "Sienna", "Raegan", "Cecilia"
]

# %%
def gen_givennames(num):
    names = []
    for i in range(num):

        if random.choice([True, False]): 
            name = random.choice(male_names) + " " + random.choice(male_names)
            if i != 0 and i % 30 == 0:
                name = f"{name}, {random.choice(male_names_en)}"
        else:
            name = random.choice(female_names) + " " + random.choice(female_names)
            if i != 0 and i % 30 == 0:
                name = f"{name}, {random.choice(female_names_en)}"
        
        names.append(name)

        with open ('files/common_givennames.txt', 'a') as f:
            f.write(name + '\n')
